# %% [markdown]
# # External Lab

# %% [markdown]
# # Part-1

# %% [markdown]
# ## About the dataset
#
# This is perhaps the best known database to be found in the pattern recognition literature. The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Attribute Information:
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. class:
#       -- Iris Setosa
#       -- Iris Versicolour
#       -- Iris Virginica

# %% [markdown]
# ### Read the dataset and store it in the dataframe named Iris

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
% matplotlib inline
import seaborn as sns
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2674a24b-da9b-4194-8bd1-bfe983526294" name="files[]" multiple disabled />
#      <output id="result-2674a24b-da9b-4194-8bd1-bfe983526294">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Iris.csv to Iris (1).csv

# %% [markdown]
# ### Find out the datatypes of each and every column

# %%
import io
Iris = pd.read_csv(io.BytesIO(uploaded['Iris.csv']))

Iris
# Out:
#      Sepal Length (in cm)  ...           Class
# 0                     5.1  ...     Iris-setosa
# 1                     4.9  ...     Iris-setosa
# 2                     4.7  ...     Iris-setosa
# 3                     4.6  ...     Iris-setosa
# 4                     5.0  ...     Iris-setosa
# 5                     5.4  ...     Iris-setosa
# 6                     4.6  ...     Iris-setosa
# 7                     5.0  ...     Iris-setosa
# 8                     4.4  ...     Iris-setosa
# 9                     4.9  ...     Iris-setosa
# 10                    5.4  ...     Iris-setosa
# 11                    4.8  ...     Iris-setosa
# 12                    4.8  ...     Iris-setosa
# 13                    4.3  ...     Iris-setosa
# 14                    5.8  ...     Iris-setosa
# 15                    5.7  ...     Iris-setosa
# 16                    5.4  ...     Iris-setosa
# 17                    5.1  ...     Iris-setosa
# 18                    5.7  ...     Iris-setosa
# 19                    5.1  ...     Iris-setosa
# 20                    5.4  ...     Iris-setosa
# 21                    5.1  ...     Iris-setosa
# 22                    4.6  ...     Iris-setosa
# 23                    5.1  ...     Iris-setosa
# 24                    4.8  ...     Iris-setosa
# 25                    5.0  ...     Iris-setosa
# 26                    5.0  ...     Iris-setosa
# 27                    5.2  ...     Iris-setosa
# 28                    5.2  ...     Iris-setosa
# 29                    4.7  ...     Iris-setosa
# ..                    ...  ...             ...
# 120                   6.9  ...  Iris-virginica
# 121                   5.6  ...  Iris-virginica
# 122                   7.7  ...  Iris-virginica
# 123                   6.3  ...  Iris-virginica
# 124                   6.7  ...  Iris-virginica
# 125                   7.2  ...  Iris-virginica
# 126                   6.2  ...  Iris-virginica
# 127                   6.1  ...  Iris-virginica
# 128                   6.4  ...  Iris-virginica
# 129                   7.2  ...  Iris-virginica
# 130                   7.4  ...  Iris-virginica
# 131                   7.9  ...  Iris-virginica
# 132                   6.4  ...  Iris-virginica
# 133                   6.3  ...  Iris-virginica
# 134                   6.1  ...  Iris-virginica
# 135                   7.7  ...  Iris-virginica
# 136                   6.3  ...  Iris-virginica
# 137                   6.4  ...  Iris-virginica
# 138                   6.0  ...  Iris-virginica
# 139                   6.9  ...  Iris-virginica
# 140                   6.7  ...  Iris-virginica
# 141                   6.9  ...  Iris-virginica
# 142                   5.8  ...  Iris-virginica
# 143                   6.8  ...  Iris-virginica
# 144                   6.7  ...  Iris-virginica
# 145                   6.7  ...  Iris-virginica
# 146                   6.3  ...  Iris-virginica
# 147                   6.5  ...  Iris-virginica
# 148                   6.2  ...  Iris-virginica
# 149                   5.9  ...  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Print top 10 & bottom 10 samples from the dataframe

# %%
## top 10 
Iris.head(10)
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  ...  Petal width (in cm)        Class
# 0                   5.1                  3.5  ...                  0.2  Iris-setosa
# 1                   4.9                  3.0  ...                  0.2  Iris-setosa
# 2                   4.7                  3.2  ...                  0.2  Iris-setosa
# 3                   4.6                  3.1  ...                  0.2  Iris-setosa
# 4                   5.0                  3.6  ...                  0.2  Iris-setosa
# 5                   5.4                  3.9  ...                  0.4  Iris-setosa
# 6                   4.6                  3.4  ...                  0.3  Iris-setosa
# 7                   5.0                  3.4  ...                  0.2  Iris-setosa
# 8                   4.4                  2.9  ...                  0.2  Iris-setosa
# 9                   4.9                  3.1  ...                  0.1  Iris-setosa
#
# [10 rows x 5 columns]

# %%
## bottom 10 
Iris.tail(10)
# Out:
#      Sepal Length (in cm)  ...           Class
# 140                   6.7  ...  Iris-virginica
# 141                   6.9  ...  Iris-virginica
# 142                   5.8  ...  Iris-virginica
# 143                   6.8  ...  Iris-virginica
# 144                   6.7  ...  Iris-virginica
# 145                   6.7  ...  Iris-virginica
# 146                   6.3  ...  Iris-virginica
# 147                   6.5  ...  Iris-virginica
# 148                   6.2  ...  Iris-virginica
# 149                   5.9  ...  Iris-virginica
#
# [10 rows x 5 columns]

# %% [markdown]
# ### Find the shape of the dataset

# %%
Iris.shape
# Out:
# (150, 5)

# %% [markdown]
# ### Set the index of the dataframe to be the first column

# %%
Iris.columns
# Out:
# Index(['Sepal Length (in cm)', 'Sepal Width in (cm)', 'Petal length (in cm)',
#        'Petal width (in cm)', 'Class'],
#       dtype='object')

# %%
## data.set_index("last_name", inplace=True)
new_index = Iris['Sepal Length (in cm)']
Iris.set_index(new_index)
# Out:
#                       Sepal Length (in cm)  ...           Class
# Sepal Length (in cm)                        ...
# 5.1                                    5.1  ...     Iris-setosa
# 4.9                                    4.9  ...     Iris-setosa
# 4.7                                    4.7  ...     Iris-setosa
# 4.6                                    4.6  ...     Iris-setosa
# 5.0                                    5.0  ...     Iris-setosa
# 5.4                                    5.4  ...     Iris-setosa
# 4.6                                    4.6  ...     Iris-setosa
# 5.0                                    5.0  ...     Iris-setosa
# 4.4                                    4.4  ...     Iris-setosa
# 4.9                                    4.9  ...     Iris-setosa
# 5.4                                    5.4  ...     Iris-setosa
# 4.8                                    4.8  ...     Iris-setosa
# 4.8                                    4.8  ...     Iris-setosa
# 4.3                                    4.3  ...     Iris-setosa
# 5.8                                    5.8  ...     Iris-setosa
# 5.7                                    5.7  ...     Iris-setosa
# 5.4                                    5.4  ...     Iris-setosa
# 5.1                                    5.1  ...     Iris-setosa
# 5.7                                    5.7  ...     Iris-setosa
# 5.1                                    5.1  ...     Iris-setosa
# 5.4                                    5.4  ...     Iris-setosa
# 5.1                                    5.1  ...     Iris-setosa
# 4.6                                    4.6  ...     Iris-setosa
# 5.1                                    5.1  ...     Iris-setosa
# 4.8                                    4.8  ...     Iris-setosa
# 5.0                                    5.0  ...     Iris-setosa
# 5.0                                    5.0  ...     Iris-setosa
# 5.2                                    5.2  ...     Iris-setosa
# 5.2                                    5.2  ...     Iris-setosa
# 4.7                                    4.7  ...     Iris-setosa
# ...                                    ...  ...             ...
# 6.9                                    6.9  ...  Iris-virginica
# 5.6                                    5.6  ...  Iris-virginica
# 7.7                                    7.7  ...  Iris-virginica
# 6.3                                    6.3  ...  Iris-virginica
# 6.7                                    6.7  ...  Iris-virginica
# 7.2                                    7.2  ...  Iris-virginica
# 6.2                                    6.2  ...  Iris-virginica
# 6.1                                    6.1  ...  Iris-virginica
# 6.4                                    6.4  ...  Iris-virginica
# 7.2                                    7.2  ...  Iris-virginica
# 7.4                                    7.4  ...  Iris-virginica
# 7.9                                    7.9  ...  Iris-virginica
# 6.4                                    6.4  ...  Iris-virginica
# 6.3                                    6.3  ...  Iris-virginica
# 6.1                                    6.1  ...  Iris-virginica
# 7.7                                    7.7  ...  Iris-virginica
# 6.3                                    6.3  ...  Iris-virginica
# 6.4                                    6.4  ...  Iris-virginica
# 6.0                                    6.0  ...  Iris-virginica
# 6.9                                    6.9  ...  Iris-virginica
# 6.7                                    6.7  ...  Iris-virginica
# 6.9                                    6.9  ...  Iris-virginica
# 5.8                                    5.8  ...  Iris-virginica
# 6.8                                    6.8  ...  Iris-virginica
# 6.7                                    6.7  ...  Iris-virginica
# 6.7                                    6.7  ...  Iris-virginica
# 6.3                                    6.3  ...  Iris-virginica
# 6.5                                    6.5  ...  Iris-virginica
# 6.2                                    6.2  ...  Iris-virginica
# 5.9                                    5.9  ...  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Use iloc function to print all the rows of the 3rd column

# %%
Iris.iloc[:,2]
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
# 5      1.7
# 6      1.4
# 7      1.5
# 8      1.4
# 9      1.5
# 10     1.5
# 11     1.6
# 12     1.4
# 13     1.1
# 14     1.2
# 15     1.5
# 16     1.3
# 17     1.4
# 18     1.7
# 19     1.5
# 20     1.7
# 21     1.5
# 22     1.0
# 23     1.7
# 24     1.9
# 25     1.6
# 26     1.6
# 27     1.5
# 28     1.4
# 29     1.6
#       ...
# 120    5.7
# 121    4.9
# 122    6.7
# 123    4.9
# 124    5.7
# 125    6.0
# 126    4.8
# 127    4.9
# 128    5.6
# 129    5.8
# 130    6.1
# 131    6.4
# 132    5.6
# 133    5.1
# 134    5.6
# 135    6.1
# 136    5.6
# 137    5.5
# 138    4.8
# 139    5.4
# 140    5.6
# 141    5.1
# 142    5.1
# 143    5.9
# 144    5.7
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: Petal length (in cm), Length: 150, dtype: float64

# %% [markdown]
# ### Slicing
# Print only the Sepal width and Sepal Length for first 10 rows

# %%
Iris.columns
# Out:
# Index(['Sepal Length (in cm)', 'Sepal Width in (cm)', 'Petal length (in cm)',
#        'Petal width (in cm)', 'Class'],
#       dtype='object')

# %%
Iris.iloc[0:10,[1,0]]
# Out:
#    Sepal Width in (cm)  Sepal Length (in cm)
# 0                  3.5                   5.1
# 1                  3.0                   4.9
# 2                  3.2                   4.7
# 3                  3.1                   4.6
# 4                  3.6                   5.0
# 5                  3.9                   5.4
# 6                  3.4                   4.6
# 7                  3.4                   5.0
# 8                  2.9                   4.4
# 9                  3.1                   4.9

# %% [markdown]
# ### Using Logical statements for indexing
# Print all the columns of row which has class name "Iris-setosa"

# %%
Iris.loc[Iris['Class']=="Iris-setosa"]
# Out:
#     Sepal Length (in cm)  Sepal Width in (cm)  ...  Petal width (in cm)        Class
# 0                    5.1                  3.5  ...                  0.2  Iris-setosa
# 1                    4.9                  3.0  ...                  0.2  Iris-setosa
# 2                    4.7                  3.2  ...                  0.2  Iris-setosa
# 3                    4.6                  3.1  ...                  0.2  Iris-setosa
# 4                    5.0                  3.6  ...                  0.2  Iris-setosa
# 5                    5.4                  3.9  ...                  0.4  Iris-setosa
# 6                    4.6                  3.4  ...                  0.3  Iris-setosa
# 7                    5.0                  3.4  ...                  0.2  Iris-setosa
# 8                    4.4                  2.9  ...                  0.2  Iris-setosa
# 9                    4.9                  3.1  ...                  0.1  Iris-setosa
# 10                   5.4                  3.7  ...                  0.2  Iris-setosa
# 11                   4.8                  3.4  ...                  0.2  Iris-setosa
# 12                   4.8                  3.0  ...                  0.1  Iris-setosa
# 13                   4.3                  3.0  ...                  0.1  Iris-setosa
# 14                   5.8                  4.0  ...                  0.2  Iris-setosa
# 15                   5.7                  4.4  ...                  0.4  Iris-setosa
# 16                   5.4                  3.9  ...                  0.4  Iris-setosa
# 17                   5.1                  3.5  ...                  0.3  Iris-setosa
# 18                   5.7                  3.8  ...                  0.3  Iris-setosa
# 19                   5.1                  3.8  ...                  0.3  Iris-setosa
# 20                   5.4                  3.4  ...                  0.2  Iris-setosa
# 21                   5.1                  3.7  ...                  0.4  Iris-setosa
# 22                   4.6                  3.6  ...                  0.2  Iris-setosa
# 23                   5.1                  3.3  ...                  0.5  Iris-setosa
# 24                   4.8                  3.4  ...                  0.2  Iris-setosa
# 25                   5.0                  3.0  ...                  0.2  Iris-setosa
# 26                   5.0                  3.4  ...                  0.4  Iris-setosa
# 27                   5.2                  3.5  ...                  0.2  Iris-setosa
# 28                   5.2                  3.4  ...                  0.2  Iris-setosa
# 29                   4.7                  3.2  ...                  0.2  Iris-setosa
# 30                   4.8                  3.1  ...                  0.2  Iris-setosa
# 31                   5.4                  3.4  ...                  0.4  Iris-setosa
# 32                   5.2                  4.1  ...                  0.1  Iris-setosa
# 33                   5.5                  4.2  ...                  0.2  Iris-setosa
# 34                   4.9                  3.1  ...                  0.1  Iris-setosa
# 35                   5.0                  3.2  ...                  0.2  Iris-setosa
# 36                   5.5                  3.5  ...                  0.2  Iris-setosa
# 37                   4.9                  3.1  ...                  0.1  Iris-setosa
# 38                   4.4                  3.0  ...                  0.2  Iris-setosa
# 39                   5.1                  3.4  ...                  0.2  Iris-setosa
# 40                   5.0                  3.5  ...                  0.3  Iris-setosa
# 41                   4.5                  2.3  ...                  0.3  Iris-setosa
# 42                   4.4                  3.2  ...                  0.2  Iris-setosa
# 43                   5.0                  3.5  ...                  0.6  Iris-setosa
# 44                   5.1                  3.8  ...                  0.4  Iris-setosa
# 45                   4.8                  3.0  ...                  0.3  Iris-setosa
# 46                   5.1                  3.8  ...                  0.2  Iris-setosa
# 47                   4.6                  3.2  ...                  0.2  Iris-setosa
# 48                   5.3                  3.7  ...                  0.2  Iris-setosa
# 49                   5.0                  3.3  ...                  0.2  Iris-setosa
#
# [50 rows x 5 columns]

# %% [markdown]
# ### Multiply Sepal Length and width and store it under the column name "SepalExtra" in the same Iris dataframe

# %%
Iris['SepalExtra']=(Iris.iloc[:,0])*(Iris.iloc[:,1])
Iris
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  ...           Class  SepalExtra
# 0                     5.1                  3.5  ...     Iris-setosa       17.85
# 1                     4.9                  3.0  ...     Iris-setosa       14.70
# 2                     4.7                  3.2  ...     Iris-setosa       15.04
# 3                     4.6                  3.1  ...     Iris-setosa       14.26
# 4                     5.0                  3.6  ...     Iris-setosa       18.00
# 5                     5.4                  3.9  ...     Iris-setosa       21.06
# 6                     4.6                  3.4  ...     Iris-setosa       15.64
# 7                     5.0                  3.4  ...     Iris-setosa       17.00
# 8                     4.4                  2.9  ...     Iris-setosa       12.76
# 9                     4.9                  3.1  ...     Iris-setosa       15.19
# 10                    5.4                  3.7  ...     Iris-setosa       19.98
# 11                    4.8                  3.4  ...     Iris-setosa       16.32
# 12                    4.8                  3.0  ...     Iris-setosa       14.40
# 13                    4.3                  3.0  ...     Iris-setosa       12.90
# 14                    5.8                  4.0  ...     Iris-setosa       23.20
# 15                    5.7                  4.4  ...     Iris-setosa       25.08
# 16                    5.4                  3.9  ...     Iris-setosa       21.06
# 17                    5.1                  3.5  ...     Iris-setosa       17.85
# 18                    5.7                  3.8  ...     Iris-setosa       21.66
# 19                    5.1                  3.8  ...     Iris-setosa       19.38
# 20                    5.4                  3.4  ...     Iris-setosa       18.36
# 21                    5.1                  3.7  ...     Iris-setosa       18.87
# 22                    4.6                  3.6  ...     Iris-setosa       16.56
# 23                    5.1                  3.3  ...     Iris-setosa       16.83
# 24                    4.8                  3.4  ...     Iris-setosa       16.32
# 25                    5.0                  3.0  ...     Iris-setosa       15.00
# 26                    5.0                  3.4  ...     Iris-setosa       17.00
# 27                    5.2                  3.5  ...     Iris-setosa       18.20
# 28                    5.2                  3.4  ...     Iris-setosa       17.68
# 29                    4.7                  3.2  ...     Iris-setosa       15.04
# ..                    ...                  ...  ...             ...         ...
# 120                   6.9                  3.2  ...  Iris-virginica       22.08
# 121                   5.6                  2.8  ...  Iris-virginica       15.68
# 122                   7.7                  2.8  ...  Iris-virginica       21.56
# 123                   6.3                  2.7  ...  Iris-virginica       17.01
# 124                   6.7                  3.3  ...  Iris-virginica       22.11
# 125                   7.2                  3.2  ...  Iris-virginica       23.04
# 126                   6.2                  2.8  ...  Iris-virginica       17.36
# 127                   6.1                  3.0  ...  Iris-virginica       18.30
# 128                   6.4                  2.8  ...  Iris-virginica       17.92
# 129                   7.2                  3.0  ...  Iris-virginica       21.60
# 130                   7.4                  2.8  ...  Iris-virginica       20.72
# 131                   7.9                  3.8  ...  Iris-virginica       30.02
# 132                   6.4                  2.8  ...  Iris-virginica       17.92
# 133                   6.3                  2.8  ...  Iris-virginica       17.64
# 134                   6.1                  2.6  ...  Iris-virginica       15.86
# 135                   7.7                  3.0  ...  Iris-virginica       23.10
# 136                   6.3                  3.4  ...  Iris-virginica       21.42
# 137                   6.4                  3.1  ...  Iris-virginica       19.84
# 138                   6.0                  3.0  ...  Iris-virginica       18.00
# 139                   6.9                  3.1  ...  Iris-virginica       21.39
# 140                   6.7                  3.1  ...  Iris-virginica       20.77
# 141                   6.9                  3.1  ...  Iris-virginica       21.39
# 142                   5.8                  2.7  ...  Iris-virginica       15.66
# 143                   6.8                  3.2  ...  Iris-virginica       21.76
# 144                   6.7                  3.3  ...  Iris-virginica       22.11
# 145                   6.7                  3.0  ...  Iris-virginica       20.10
# 146                   6.3                  2.5  ...  Iris-virginica       15.75
# 147                   6.5                  3.0  ...  Iris-virginica       19.50
# 148                   6.2                  3.4  ...  Iris-virginica       21.08
# 149                   5.9                  3.0  ...  Iris-virginica       17.70
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Find out the mean and variance for each column but for class column

# %%
Iris.mean()
# Out:
# Sepal Length (in cm)     5.843333
# Sepal Width in (cm)      3.054000
# Petal length (in cm)     3.758667
# Petal width (in cm)      1.198667
# SepalExtra              17.806533
# dtype: float64

# %%
Iris.var()
# Out:
# Sepal Length (in cm)     0.685694
# Sepal Width in (cm)      0.188004
# Petal length (in cm)     3.113179
# Petal width (in cm)      0.582414
# SepalExtra              11.348090
# dtype: float64

# %% [markdown]
# ### Write a function that accepts two numbers as input and prints them - Pass the Sepal length and sepal width of 5th row and print the output

# %%
a,b = Iris.iloc[4,:2]

def num(a,b):
  return('Sepal Length is {0} and Sepal Width is {1}'.format(a,b))
  

num(a,b)
# Out:
# 'Sepal Length is 5.0 and Sepal Width is 3.6'

# %%
Iris.iloc[0,:3]
data
# Out:
# Sepal Length (in cm)    4.6
# Sepal Width in (cm)     3.4
# Name: 6, dtype: object

# %% [markdown]
# ### Find the range of all the columns in the dataset
#
# *Range = Max value - Min value (in the column)*

# %%
(Iris.iloc[:,0:4].max())-(Iris.iloc[:,0:4].min())
# Out:
# Sepal Length (in cm)    3.6
# Sepal Width in (cm)     2.4
# Petal length (in cm)    5.9
# Petal width (in cm)     2.4
# dtype: float64

# %% [markdown]
# ### Sort the entire dataset according to the column Petal width

# %%
Iris.sort_values('Petal width (in cm)')
# Out:
#      Sepal Length (in cm)  ...           Class
# 32                    5.2  ...     Iris-setosa
# 13                    4.3  ...     Iris-setosa
# 37                    4.9  ...     Iris-setosa
# 9                     4.9  ...     Iris-setosa
# 12                    4.8  ...     Iris-setosa
# 34                    4.9  ...     Iris-setosa
# 0                     5.1  ...     Iris-setosa
# 27                    5.2  ...     Iris-setosa
# 28                    5.2  ...     Iris-setosa
# 29                    4.7  ...     Iris-setosa
# 30                    4.8  ...     Iris-setosa
# 33                    5.5  ...     Iris-setosa
# 36                    5.5  ...     Iris-setosa
# 38                    4.4  ...     Iris-setosa
# 39                    5.1  ...     Iris-setosa
# 42                    4.4  ...     Iris-setosa
# 46                    5.1  ...     Iris-setosa
# 47                    4.6  ...     Iris-setosa
# 48                    5.3  ...     Iris-setosa
# 49                    5.0  ...     Iris-setosa
# 25                    5.0  ...     Iris-setosa
# 24                    4.8  ...     Iris-setosa
# 35                    5.0  ...     Iris-setosa
# 3                     4.6  ...     Iris-setosa
# 2                     4.7  ...     Iris-setosa
# 7                     5.0  ...     Iris-setosa
# 8                     4.4  ...     Iris-setosa
# 10                    5.4  ...     Iris-setosa
# 4                     5.0  ...     Iris-setosa
# 11                    4.8  ...     Iris-setosa
# ..                    ...  ...             ...
# 111                   6.4  ...  Iris-virginica
# 121                   5.6  ...  Iris-virginica
# 122                   7.7  ...  Iris-virginica
# 147                   6.5  ...  Iris-virginica
# 113                   5.7  ...  Iris-virginica
# 131                   7.9  ...  Iris-virginica
# 110                   6.5  ...  Iris-virginica
# 139                   6.9  ...  Iris-virginica
# 102                   7.1  ...  Iris-virginica
# 112                   6.8  ...  Iris-virginica
# 105                   7.6  ...  Iris-virginica
# 124                   6.7  ...  Iris-virginica
# 128                   6.4  ...  Iris-virginica
# 117                   7.7  ...  Iris-virginica
# 132                   6.4  ...  Iris-virginica
# 104                   6.5  ...  Iris-virginica
# 120                   6.9  ...  Iris-virginica
# 115                   6.4  ...  Iris-virginica
# 148                   6.2  ...  Iris-virginica
# 141                   6.9  ...  Iris-virginica
# 143                   6.8  ...  Iris-virginica
# 145                   6.7  ...  Iris-virginica
# 118                   7.7  ...  Iris-virginica
# 135                   7.7  ...  Iris-virginica
# 136                   6.3  ...  Iris-virginica
# 140                   6.7  ...  Iris-virginica
# 114                   5.8  ...  Iris-virginica
# 100                   6.3  ...  Iris-virginica
# 144                   6.7  ...  Iris-virginica
# 109                   7.2  ...  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Remove the new column "SepalExtra" from the dataframe

# %%
del Iris['SepalExtra']
Iris
# Out:
#      Sepal Length (in cm)  ...           Class
# 0                     5.1  ...     Iris-setosa
# 1                     4.9  ...     Iris-setosa
# 2                     4.7  ...     Iris-setosa
# 3                     4.6  ...     Iris-setosa
# 4                     5.0  ...     Iris-setosa
# 5                     5.4  ...     Iris-setosa
# 6                     4.6  ...     Iris-setosa
# 7                     5.0  ...     Iris-setosa
# 8                     4.4  ...     Iris-setosa
# 9                     4.9  ...     Iris-setosa
# 10                    5.4  ...     Iris-setosa
# 11                    4.8  ...     Iris-setosa
# 12                    4.8  ...     Iris-setosa
# 13                    4.3  ...     Iris-setosa
# 14                    5.8  ...     Iris-setosa
# 15                    5.7  ...     Iris-setosa
# 16                    5.4  ...     Iris-setosa
# 17                    5.1  ...     Iris-setosa
# 18                    5.7  ...     Iris-setosa
# 19                    5.1  ...     Iris-setosa
# 20                    5.4  ...     Iris-setosa
# 21                    5.1  ...     Iris-setosa
# 22                    4.6  ...     Iris-setosa
# 23                    5.1  ...     Iris-setosa
# 24                    4.8  ...     Iris-setosa
# 25                    5.0  ...     Iris-setosa
# 26                    5.0  ...     Iris-setosa
# 27                    5.2  ...     Iris-setosa
# 28                    5.2  ...     Iris-setosa
# 29                    4.7  ...     Iris-setosa
# ..                    ...  ...             ...
# 120                   6.9  ...  Iris-virginica
# 121                   5.6  ...  Iris-virginica
# 122                   7.7  ...  Iris-virginica
# 123                   6.3  ...  Iris-virginica
# 124                   6.7  ...  Iris-virginica
# 125                   7.2  ...  Iris-virginica
# 126                   6.2  ...  Iris-virginica
# 127                   6.1  ...  Iris-virginica
# 128                   6.4  ...  Iris-virginica
# 129                   7.2  ...  Iris-virginica
# 130                   7.4  ...  Iris-virginica
# 131                   7.9  ...  Iris-virginica
# 132                   6.4  ...  Iris-virginica
# 133                   6.3  ...  Iris-virginica
# 134                   6.1  ...  Iris-virginica
# 135                   7.7  ...  Iris-virginica
# 136                   6.3  ...  Iris-virginica
# 137                   6.4  ...  Iris-virginica
# 138                   6.0  ...  Iris-virginica
# 139                   6.9  ...  Iris-virginica
# 140                   6.7  ...  Iris-virginica
# 141                   6.9  ...  Iris-virginica
# 142                   5.8  ...  Iris-virginica
# 143                   6.8  ...  Iris-virginica
# 144                   6.7  ...  Iris-virginica
# 145                   6.7  ...  Iris-virginica
# 146                   6.3  ...  Iris-virginica
# 147                   6.5  ...  Iris-virginica
# 148                   6.2  ...  Iris-virginica
# 149                   5.9  ...  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Take only the top 10 rows of the dataset with only first 3 columns and store it in a dataframe named "IrisSubset"

# %%
IrisSubset = Iris.iloc[0:10,0:3]
IrisSubset
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5

# %% [markdown]
# # Part-2

# %% [markdown]
# ## The dataset HR contains information collected from the survey floated by a HR within the company.
#
#
# As a part of this lab, you are expected to answer the below questions

# %% [markdown]
# ### Import numpy and Pandas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Import the dataset (Note: The dataset is in .txt format) - Make sure to use delimiters

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
data = pd.read_csv('HR_external.txt',delimiter="	")
data.head()
# Out:
#   Individual  Attrition  ...  YearsSinceLastPromotion  YearsWithCurrManager
# 0        Ind1       Yes  ...                        0                     5
# 1        Ind2        No  ...                        1                     7
# 2        Ind3       Yes  ...                        0                     0
# 3        Ind4        No  ...                        3                     0
# 4        Ind5        No  ...                        2                     2
#
# [5 rows x 35 columns]

# %% [markdown]
# ### Print the no of rows and columns in the dataset

# %%
data.shape
# Out:
# (1470, 35)

# %%
# Out:
# Index(['Individual ', 'Attrition', 'Age', 'BusinessTravel', 'DailyRate',
#        'Department', 'DistanceFromHome', 'Education', 'EducationField',
#        'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate',
#        'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# ### Find out the type of each and every column in the dataset

# %%
data.dtypes
# Out:
# Individual                  object
# Attrition                   object
# Age                          int64
# BusinessTravel               int64
# DailyRate                    int64
# Department                   int64
# DistanceFromHome             int64
# Education                    int64
# EducationField               int64
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                       int64
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                      int64
# JobSatisfaction              int64
# MaritalStatus                int64
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                     int64
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# YearsAtCompany               int64
# YearsInCurrentRole           int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %% [markdown]
# ### Print out all the rows from 3rd column to 10th columns

# %%
data.iloc[:,3:10]
# Out:
#       BusinessTravel  DailyRate  ...  EducationField  EmployeeCount
# 0                  1       1102  ...               1              1
# 1                  2        279  ...               1              1
# 2                  1       1373  ...               6              1
# 3                  2       1392  ...               1              1
# 4                  1        591  ...               2              1
# 5                  2       1005  ...               1              1
# 6                  1       1324  ...               2              1
# 7                  1       1358  ...               1              1
# 8                  2        216  ...               1              1
# 9                  1       1299  ...               2              1
# 10                 1        809  ...               2              1
# 11                 1        153  ...               1              1
# 12                 1        670  ...               1              1
# 13                 1       1346  ...               2              1
# 14                 1        103  ...               1              1
# 15                 1       1389  ...               1              1
# 16                 1        334  ...               1              1
# 17                 3       1123  ...               2              1
# 18                 1       1219  ...               1              1
# 19                 1        371  ...               1              1
# 20                 3        673  ...               6              1
# 21                 1       1218  ...               1              1
# 22                 1        419  ...               1              1
# 23                 1        391  ...               1              1
# 24                 1        699  ...               2              1
# 25                 1       1282  ...               6              1
# 26                 2       1125  ...               1              1
# 27                 1        691  ...               3              1
# 28                 1        477  ...               2              1
# 29                 1        705  ...               3              1
# ...              ...        ...  ...             ...            ...
# 1440               2        688  ...               1              1
# 1441               3        667  ...               1              1
# 1442               1       1092  ...               2              1
# 1443               1        300  ...               1              1
# 1444               1        310  ...               4              1
# 1445               1        582  ...               1              1
# 1446               1        704  ...               3              1
# 1447               3        301  ...               3              1
# 1448               1        930  ...               1              1
# 1449               1        529  ...               4              1
# 1450               1       1146  ...               1              1
# 1451               1        345  ...               1              1
# 1452               2        878  ...               1              1
# 1453               1       1120  ...               3              1
# 1454               1        374  ...               1              1
# 1455               1       1322  ...               1              1
# 1456               2       1199  ...               1              1
# 1457               1       1194  ...               2              1
# 1458               1        287  ...               1              1
# 1459               1       1378  ...               6              1
# 1460               1        468  ...               2              1
# 1461               1        410  ...               3              1
# 1462               1        722  ...               3              1
# 1463               3        325  ...               2              1
# 1464               1       1167  ...               6              1
# 1465               2        884  ...               2              1
# 1466               1        613  ...               2              1
# 1467               1        155  ...               1              1
# 1468               2       1023  ...               2              1
# 1469               1        628  ...               2              1
#
# [1470 rows x 7 columns]

# %% [markdown]
# ### Find out the no of male & female employees in the company
#
# *Hint: Use can use a condition to find out the no of 1s and 0s in gender and sum it*

# %%
data['Gender'].value_counts()
# Out:
# 1    882
# 2    588
# Name: Gender, dtype: int64

# %% [markdown]
# ### Find out the IQR for the column - Age
#
# *Hint: IQR - Interquartile range = 75th percentile - 25th percentile*

# %%
IQR = (data['Age'].quantile(.75))-(data['Age'].quantile(.25))
IQR
# Out:
# 13.0

# %% [markdown]
# ### Find out the mean, median and variance for the column - DailyRate

# %%
data['DailyRate'].mean()
# Out:
# 802.4857142857143

# %%
data['DailyRate'].median()
# Out:
# 802.0

# %%
data['DailyRate'].var()
# Out:
# 162819.59373723628

# %% [markdown]
# ### Plot the attrition column (Since it is a categorical variable, chose the plot accordingly)

# %%
data.columns
# Out:
# Index(['Individual ', 'Attrition', 'Age', 'BusinessTravel', 'DailyRate',
#        'Department', 'DistanceFromHome', 'Education', 'EducationField',
#        'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate',
#        'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
sns.catplot(x='Attrition',kind='count',hue='Attrition',data=data,orient="h")

plt.show()

# %% [markdown]
# ### Plot Total working years using matplotlib plot function

# %%
plt.hist(data['TotalWorkingYears'], normed=True, bins=30)
plt.ylabel('TotalWorkingYears')
plt.legend()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# No handles with labels found to put in legend.
