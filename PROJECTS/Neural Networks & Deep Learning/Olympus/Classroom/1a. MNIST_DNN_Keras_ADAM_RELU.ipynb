# %% [markdown]
# ### Load tensorflow

# %%
import tensorflow as tf
tf.set_random_seed(42)

# %% [markdown]
# ### Collect Data

# %%
(trainX, trainY),(testX, testY) = tf.keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# ### Convert Output label to multiple values

# %%
trainY = tf.keras.utils.to_categorical(trainY, num_classes=10)
testY = tf.keras.utils.to_categorical(testY, num_classes=10)

# %% [markdown]
# ## Build the Graph

# %%
#Initialize model, reshape & normalize data
tf.keras.backend.clear_session()
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Reshape((784,),input_shape=(28,28,)))
model.add(tf.keras.layers.BatchNormalization())

# %% [markdown]
# ### Apply ReLU and Dropout

# %%
#Hidden layers
model.add(tf.keras.layers.Dense(200, activation='relu', name='Layer_1'))

model.add(tf.keras.layers.BatchNormalization())

model.add(tf.keras.layers.Dense(100, activation='relu', name='Layer_2'))
model.add(tf.keras.layers.BatchNormalization())
#Dropout layer
model.add(tf.keras.layers.Dropout(0.5))

#Hidden layers
model.add(tf.keras.layers.Dense(60, activation='relu', name='Layer_3'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dense(30, activation='relu', name='Layer_4'))

#Dropout layer
model.add(tf.keras.layers.Dropout(0.3))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
#Output layer
model.add(tf.keras.layers.Dense(10, activation='softmax', name='Output'))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape (Reshape)            (None, 784)               0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 784)               3136
# _________________________________________________________________
# Layer_1 (Dense)              (None, 200)               157000
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 200)               800
# _________________________________________________________________
# Layer_2 (Dense)              (None, 100)               20100
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 100)               400
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# Layer_3 (Dense)              (None, 60)                6060
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 60)                240
# _________________________________________________________________
# Layer_4 (Dense)              (None, 30)                1830
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30)                0
# _________________________________________________________________
# Output (Dense)               (None, 10)                310
# =================================================================
# Total params: 189,876
# Trainable params: 187,588
# Non-trainable params: 2,288
# _________________________________________________________________

# %% [markdown]
# ### Execute Graph

# %%
chec

# %%
#Train the model
model.fit(trainX,trainY,
          validation_data=(testX,testY),
          epochs=40,
          batch_size=32)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/40
# 60000/60000 [==============================] - 12s 194us/sample - loss: 0.5483 - acc: 0.8404 - val_loss: 0.2802 - val_acc: 0.9502
# Epoch 2/40
# 60000/60000 [==============================] - 11s 187us/sample - loss: 0.2795 - acc: 0.9257 - val_loss: 0.2688 - val_acc: 0.9598
# Epoch 3/40
# 60000/60000 [==============================] - 11s 184us/sample - loss: 0.2249 - acc: 0.9413 - val_loss: 0.6392 - val_acc: 0.9640
# Epoch 4/40
# 60000/60000 [==============================] - 11s 182us/sample - loss: 0.1928 - acc: 0.9490 - val_loss: 0.5718 - val_acc: 0.9648
# Epoch 5/40
# 60000/60000 [==============================] - 11s 181us/sample - loss: 0.1710 - acc: 0.9556 - val_loss: 0.4224 - val_acc: 0.9685
# Epoch 6/40
# 60000/60000 [==============================] - 11s 181us/sample - loss: 0.1561 - acc: 0.9592 - val_loss: 0.8796 - val_acc: 0.9690
# Epoch 7/40
# 60000/60000 [==============================] - 11s 183us/sample - loss: 0.1436 - acc: 0.9625 - val_loss: 0.5286 - val_acc: 0.9719
# Epoch 8/40
# 60000/60000 [==============================] - 11s 181us/sample - loss: 0.1305 - acc: 0.9662 - val_loss: 0.7261 - val_acc: 0.9675
# Epoch 9/40
# 60000/60000 [==============================] - 11s 185us/sample - loss: 0.1230 - acc: 0.9668 - val_loss: 1.1418 - val_acc: 0.9720
# Epoch 10/40
# 60000/60000 [==============================] - 11s 190us/sample - loss: 0.1157 - acc: 0.9697 - val_loss: 0.7152 - val_acc: 0.9721
# Epoch 11/40
# 60000/60000 [==============================] - 11s 180us/sample - loss: 0.1107 - acc: 0.9706 - val_loss: 0.9512 - val_acc: 0.9725
# Epoch 12/40
# 60000/60000 [==============================] - 11s 185us/sample - loss: 0.1032 - acc: 0.9725 - val_loss: 0.5769 - val_acc: 0.9746
# Epoch 13/40
# 60000/60000 [==============================] - 11s 180us/sample - loss: 0.0985 - acc: 0.9738 - val_loss: 0.9478 - val_acc: 0.9728
# Epoch 14/40
# 60000/60000 [==============================] - 11s 183us/sample - loss: 0.0950 - acc: 0.9744 - val_loss: 0.7293 - val_acc: 0.9733
# Epoch 15/40
# 60000/60000 [==============================] - 11s 184us/sample - loss: 0.0948 - acc: 0.9748 - val_loss: 0.7037 - val_acc: 0.9745
# Epoch 16/40
# 60000/60000 [==============================] - 11s 183us/sample - loss: 0.0900 - acc: 0.9757 - val_loss: 0.9256 - val_acc: 0.9744
# Epoch 17/40
# 60000/60000 [==============================] - 11s 181us/sample - loss: 0.0881 - acc: 0.9764 - val_loss: 0.5283 - val_acc: 0.9736
# Epoch 18/40
# 60000/60000 [==============================] - 11s 184us/sample - loss: 0.0835 - acc: 0.9770 - val_loss: 0.6352 - val_acc: 0.9739
# Epoch 19/40
# 60000/60000 [==============================] - 11s 182us/sample - loss: 0.0816 - acc: 0.9784 - val_loss: 0.6623 - val_acc: 0.9735
# Epoch 20/40
# 60000/60000 [==============================] - 11s 185us/sample - loss: 0.0772 - acc: 0.9799 - val_loss: 0.8839 - val_acc: 0.9732
# Epoch 21/40
# 60000/60000 [==============================] - 11s 185us/sample - loss: 0.0751 - acc: 0.9792 - val_loss: 0.7185 - val_acc: 0.9729
# Epoch 22/40
# 60000/60000 [==============================] - 11s 185us/sample - loss: 0.0744 - acc: 0.9791 - val_loss: 0.5577 - val_acc: 0.9741
# Epoch 23/40
# 60000/60000 [==============================] - 11s 188us/sample - loss: 0.0727 - acc: 0.9802 - val_loss: 0.5128 - val_acc: 0.9739
# Epoch 24/40
# 60000/60000 [==============================] - 11s 184us/sample - loss: 0.0691 - acc: 0.9808 - val_loss: 0.8807 - val_acc: 0.9747
# Epoch 25/40
# 60000/60000 [==============================] - 11s 181us/sample - loss: 0.0694 - acc: 0.9810 - val_loss: 0.8004 - val_acc: 0.9742
# Epoch 26/40
# 60000/60000 [==============================] - 11s 182us/sample - loss: 0.0656 - acc: 0.9824 - val_loss: 0.9389 - val_acc: 0.9749
# Epoch 27/40
# 60000/60000 [==============================] - 11s 183us/sample - loss: 0.0663 - acc: 0.9822 - val_loss: 0.5257 - val_acc: 0.9752
# Epoch 28/40
# 60000/60000 [==============================] - 11s 182us/sample - loss: 0.0632 - acc: 0.9830 - val_loss: 0.5112 - val_acc: 0.9738
# Epoch 29/40
# 60000/60000 [==============================] - 11s 185us/sample - loss: 0.0623 - acc: 0.9830 - val_loss: 0.7443 - val_acc: 0.9746
# Epoch 30/40
# 60000/60000 [==============================] - 11s 180us/sample - loss: 0.0625 - acc: 0.9829 - val_loss: 0.5117 - val_acc: 0.9751
# Epoch 31/40
# 60000/60000 [==============================] - 11s 179us/sample - loss: 0.0602 - acc: 0.9835 - val_loss: 0.6267 - val_acc: 0.9744
# Epoch 32/40
# 60000/60000 [==============================] - 11s 180us/sample - loss: 0.0577 - acc: 0.9845 - val_loss: 0.7122 - val_acc: 0.9757
# Epoch 33/40
# 60000/60000 [==============================] - 11s 180us/sample - loss: 0.0577 - acc: 0.9844 - val_loss: 1.5734 - val_acc: 0.9738
# Epoch 34/40
# 60000/60000 [==============================] - 11s 183us/sample - loss: 0.0582 - acc: 0.9839 - val_loss: 0.7479 - val_acc: 0.9745
# Epoch 35/40
# 60000/60000 [==============================] - 11s 181us/sample - loss: 0.0549 - acc: 0.9844 - val_loss: 0.5854 - val_acc: 0.9730
# Epoch 36/40
# 60000/60000 [==============================] - 11s 182us/sample - loss: 0.0515 - acc: 0.9858 - val_loss: 0.8360 - val_acc: 0.9748
# Epoch 37/40
# 60000/60000 [==============================] - 11s 185us/sample - loss: 0.0528 - acc: 0.9855 - val_loss: 0.7903 - val_acc: 0.9764
# Epoch 38/40
# 60000/60000 [==============================] - 12s 193us/sample - loss: 0.0518 - acc: 0.9866 - val_loss: 1.1493 - val_acc: 0.9735
# Epoch 39/40
# 60000/60000 [==============================] - 11s 181us/sample - loss: 0.0521 - acc: 0.9860 - val_loss: 0.8088 - val_acc: 0.9742
# Epoch 40/40
# 60000/60000 [==============================] - 11s 182us/sample - loss: 0.0522 - acc: 0.9864 - val_loss: 0.9154 - val_acc: 0.9768

# %%
model.save('dnn_1.h5')

# %%
model = tf.keras.models.load_model('dnn_1.h5')
# Out:
# W0727 12:18:32.602550 140290326050688 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0727 12:18:32.603763 140290326050688 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:97: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0727 12:18:32.682847 140290326050688 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
#Train the model
model.fit(trainX,trainY,
          epochs=20,
          initial_epoch=10,
          validation_data=(testX,testY),
          batch_size=32)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 11/20
# 60000/60000 [==============================] - 11s 190us/sample - loss: 0.0499 - acc: 0.9867 - val_loss: 0.5836 - val_acc: 0.9753
# Epoch 12/20
# 60000/60000 [==============================] - 11s 184us/sample - loss: 0.0513 - acc: 0.9868 - val_loss: 0.8302 - val_acc: 0.9752
# Epoch 13/20
# 60000/60000 [==============================] - 11s 185us/sample - loss: 0.0485 - acc: 0.9863 - val_loss: 1.1980 - val_acc: 0.9743
# Epoch 14/20
# 60000/60000 [==============================] - 11s 181us/sample - loss: 0.0482 - acc: 0.9868 - val_loss: 0.7073 - val_acc: 0.9727
# Epoch 15/20
# 60000/60000 [==============================] - 11s 185us/sample - loss: 0.0492 - acc: 0.9867 - val_loss: 0.8477 - val_acc: 0.9757
# Epoch 16/20
# 60000/60000 [==============================] - 11s 183us/sample - loss: 0.0478 - acc: 0.9866 - val_loss: 0.7302 - val_acc: 0.9754
# Epoch 17/20
# 60000/60000 [==============================] - 11s 185us/sample - loss: 0.0492 - acc: 0.9868 - val_loss: 0.8885 - val_acc: 0.9765
# Epoch 18/20
# 60000/60000 [==============================] - 11s 187us/sample - loss: 0.0464 - acc: 0.9871 - val_loss: 1.0071 - val_acc: 0.9752
# Epoch 19/20
# 60000/60000 [==============================] - 11s 187us/sample - loss: 0.0428 - acc: 0.9883 - val_loss: 0.8659 - val_acc: 0.9753
# Epoch 20/20
# 60000/60000 [==============================] - 11s 186us/sample - loss: 0.0481 - acc: 0.9872 - val_loss: 1.1036 - val_acc: 0.9740

# %%
# ?model.fit
